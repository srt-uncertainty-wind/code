# %%
import os
import numpy as np
import pandas as pd
from scipy.io import loadmat
from sklearn.ensemble import RandomForestClassifier
import random

# 指定文件夹路径
download_save_path = 'E:/Dataset/wind_shear/Data_Download'
exception_save_path = '../Dataset/Exception_Data'
plt_save_path = '../result/WSHR/figures'

# 指定文件夹名称
selected_folder_name = 'Tail_652_1'

# 生成全局和异常mat文件名称集
download_folder_path = os.path.join(download_save_path, selected_folder_name)
exception_folder_path = os.path.join(exception_save_path, selected_folder_name)
download_mat_name_list = os.listdir(download_folder_path)
exception_mat_name_list = os.listdir(exception_folder_path)

# 指定采样数据存储路径
sample_save_path = 'E:/Dataset/wind_shear/Samples'

# # 获取文件夹下的所有文件名称
# dowload_folder_names = [item for item in os.listdir(download_save_path) if os.path.isdir(os.path.join(download_save_path, item))]
# exception_folder_names = [item for item in os.listdir(exception_save_path) if os.path.isdir(os.path.join(exception_save_path, item))]
# instruction_folder_names = ["@Instructions"]

# # 生成所有文件夹路径
# dowload_folder_paths = [os.path.join(download_save_path, item) for item in dowload_folder_names]
# exception_folder_paths = [os.path.join(exception_save_path, item) for item in exception_folder_names]

# %%
# 给定除编号变量外的全状态变量名字典
group_names_list = ["mechanism", "power", "control", "external", "recorder", "unclassified"]
group_lens_dict = {}

var_group_mechanism = ["AIL_1", "AIL_2", "FLAP", "ELEV_1", "ELEV_2", "RUDD", "SPL_1", "SPL_2", "SPLG", "SPLY", "ABRK", "BPGR_1", "BPGR_2", "BPYR_1", "BPYR_2", "MSQT_1", "MSQT_2", "NSQT", "BLV", "CALT", "PACK", "WOW", 
                       "AOA1", "AOA2", "GLS", "PTCH", "ROLL", 
                       "TH", "MH", "TAS", "CASM", "GS", "IVV",
                       "VRTG", "LATG", "LONG", "FPAC", "CTAC"]
var_group_power = ["N2_1", "N2_2", "N2_3", "N2_4",
                   "ECYC_1", "ECYC_2", "ECYC_3", "ECYC_4", "EHRS_1", "EHRS_2", "EHRS_3", "EHRS_4", "VIB_1", "VIB_2", "VIB_3", "VIB_4", "FADS", "HYDG", "HYDY",
                   "N1_1", "N1_2", "N1_3", "N1_4", "N1T", "FF_1", "FF_2", "FF_3", "FF_4", "FQTY_1", "FQTY_2", "FQTY_3", "FQTY_4", "OIP_1", "OIP_2", "OIP_3", "OIP_4", "OIT_1", "OIT_2", "OIT_3", "OIT_4", "OIPL", "EGT_1", "EGT_2", "EGT_3", "EGT_4",
                   "LGDN", "LGUP"]
var_group_control = ["CRSS", "HDGS", "A_T", "APFD", "DFGS", "FGC3", "PUSH", "PTRM", "TCAS",
                     "ILSF", "RUDP", "CCPC", "CCPF", "CWPC", "CWPF", "PLA_1", "PLA_2", "PLA_3", "PLA_4",
                     "SNAP", "TMODE", "EAI", "TAI", "WAI_1", "WAI_2", 
                     "APUF", "FADF", "FIRE_1", "FIRE_2", "FIRE_3", "FIRE_4", "GPWS", "MW", "POVT", "SHKR", "SMOK", "TOCW"]
var_group_external = ["ALT", "ALTR", "WS", "WD", "PI", "PS", "PT", "SAT", "TAT",
                      "DA", "TRK", "TRKM", "LOC", "LATP", "LONP"]
var_group_recorder = ["DWPT", "PH", 
                     "ACMT", "FRMC", "GMT_HOUR", "GMT_MINUTE", "GMT_SEC"]
var_group_unclassified = ["ATEN", "EVNT", "HF1", "HF2", "VHF1", "VHF2", "VHF3", "LMOD", "VMODE", "MACH", "MNS", "MRK", "N1C", "N1CO", "SMKB", "VAR_1107", "VAR_2670", "VAR_5107", "VAR_6670"]

all_var_groups_dict = {"mechanism": var_group_mechanism, "power": var_group_power, "control": var_group_control, "external": var_group_external, "recorder": var_group_recorder, "unclassified": var_group_unclassified}
for group_name, var_list in all_var_groups_dict.items():
    group_lens_dict[group_name] = len(var_list)
    print(f"{group_name}: {len(var_list)}")
print(f"\n{sum(group_lens_dict.values())} variables in total")
# Out:
# mechanism: 38
# power: 47
# control: 37
# external: 15
# recorder: 7
# unclassified: 19
#
# 163 variables in total

# %%
# 初始化非时序无编号全状态数据存储array，idx=0为WSHR
sampling_data_array = [[] for i in range(163+1)]

# 读取mat文件并整合数据
for mat_name in download_mat_name_list:
    mat_path = os.path.join(download_folder_path, mat_name)
    mat = loadmat(mat_path)

    idx = 0
    wshr_data = mat["WSHR"][0][0][0]
    
    # 如果是异常文件，读取所有数据
    if mat_name in exception_mat_name_list:
        sampling_data_array[idx].extend(wshr_data)
        for group_name, var_list in all_var_groups_dict.items():
            for var_name in var_list:
                idx += 1
                # 对每个变量按照rate进行下采样或过采样，对长为n+1的数据，抓取前n个全变量为输入，后n个有缺变量为输出
                var_data, var_rate = mat[var_name][0][0][0], mat[var_name][0][0][1][0][0]
                if var_rate == 1:
                    sampling_data = var_data
                elif var_rate > 1: # 进行下采样
                    sampling_data = random.sample(var_data.tolist(), k=len(wshr_data))
                else:
                    sampling_data = random.choices(var_data, k=len(wshr_data))
                sampling_data_array[idx].extend(sampling_data)
    
    # 如果不是异常文件但记录时长少于320s，读取所有数据
    elif mat_name not in exception_mat_name_list and len(wshr_data) <= 320:
        sampling_data_array[idx].extend(wshr_data)
        for group_name, var_list in all_var_groups_dict.items():
            for var_name in var_list:
                idx += 1
                # 对每个变量按照rate进行下采样或过采样，对长为n+1的数据，抓取前n个全变量为输入，后n个有缺变量为输出
                var_data, var_rate = mat[var_name][0][0][0], mat[var_name][0][0][1][0][0]
                if var_rate == 1:
                    sampling_data = var_data
                elif var_rate > 1: # 进行下采样
                    sampling_data = random.sample(var_data.tolist(), k=len(wshr_data))
                else:
                    sampling_data = random.choices(var_data, k=len(wshr_data))
                sampling_data_array[idx].extend(sampling_data)
    
    # 如果不是异常文件且记录时长多于320s，读取低空160s的数据
    else:
        sampling_data_array[idx].extend(wshr_data[:160])
        sampling_data_array[idx].extend(wshr_data[-160:])
        for group_name, var_list in all_var_groups_dict.items():
            for var_name in var_list:
                idx += 1
                # 对每个变量按照rate进行下采样或过采样，对长为n+1的数据，抓取前n个全变量为输入，后n个有缺变量为输出
                var_data, var_rate = mat[var_name][0][0][0], mat[var_name][0][0][1][0][0]
                if var_rate == 1:
                    sampling_data = var_data
                elif var_rate > 1: # 进行下采样
                    sampling_data = random.sample(var_data.tolist(), k=len(wshr_data))
                else:
                    sampling_data = random.choices(var_data, k=len(wshr_data))
                sampling_data_array[idx].extend(sampling_data[:160])
                sampling_data_array[idx].extend(sampling_data[-160:])
    print(f"{mat_name} sampling done")

# 转化并存储数据为npy
sampling_data_array = np.array(sampling_data_array)
np.save(os.path.join(sample_save_path, 'sampling_data_array.npy'), sampling_data_array)
# Out:
# 652200101092009.mat sampling done
# 652200101092046.mat sampling done
# 652200101100441.mat sampling done
# 652200101111519.mat sampling done
# 652200101111622.mat sampling done
# 652200101112303.mat sampling done
# 652200101120916.mat sampling done
# 652200101121117.mat sampling done
# 652200101121118.mat sampling done
# 652200101121218.mat sampling done
# 652200101121341.mat sampling done
# 652200101121444.mat sampling done
# 652200101121611.mat sampling done
# 652200101130002.mat sampling done
# 652200101130451.mat sampling done
# 652200101130756.mat sampling done
# 652200101130931.mat sampling done
# 652200101131142.mat sampling done
# 652200101131357.mat sampling done
# 652200101131605.mat sampling done
# 652200101131757.mat sampling done
# 652200101132030.mat sampling done
# 652200101140504.mat sampling done
# 652200101141138.mat sampling done
# 652200101141354.mat sampling done
# 652200101141639.mat sampling done
# 652200101141816.mat sampling done
# 652200101142019.mat sampling done
# 652200101150517.mat sampling done
# 652200101150711.mat sampling done
# 652200101150902.mat sampling done
# 652200101151114.mat sampling done
# 652200101151334.mat sampling done
# 652200101151604.mat sampling done
# 652200101151809.mat sampling done
# 652200101152021.mat sampling done
# 652200101152205.mat sampling done
# 652200101160310.mat sampling done
# 652200101160429.mat sampling done
# 652200101160654.mat sampling done
# 652200101161056.mat sampling done
# 652200101161505.mat sampling done
# 652200101170655.mat sampling done
# 652200101171130.mat sampling done
# 652200101171310.mat sampling done
# 652200101171552.mat sampling done
# 652200101171653.mat sampling done
# 652200101171835.mat sampling done
# 652200101180702.mat sampling done
# 652200101180948.mat sampling done
# 652200101181238.mat sampling done
# 652200101181533.mat sampling done
# 652200101181702.mat sampling done
# 652200101181849.mat sampling done
# 652200101190349.mat sampling done
# 652200101190631.mat sampling done
# 652200101190800.mat sampling done
# 652200101191106.mat sampling done
# 652200101191325.mat sampling done
# 652200101191656.mat sampling done
# 652200101200553.mat sampling done
# 652200101200802.mat sampling done
# 652200101201116.mat sampling done
# 652200101201352.mat sampling done
# 652200101201529.mat sampling done
# 652200101201735.mat sampling done
# 652200101210353.mat sampling done
# 652200101210552.mat sampling done
# 652200101210746.mat sampling done
# 652200101211123.mat sampling done
# 652200101211438.mat sampling done
# 652200101211934.mat sampling done
# 652200101220441.mat sampling done
# 652200101220604.mat sampling done
# 652200101220852.mat sampling done
# 652200101220917.mat sampling done
# 652200101221136.mat sampling done
# 652200101221333.mat sampling done
# 652200101230313.mat sampling done
# 652200101231019.mat sampling done
# 652200101231126.mat sampling done
# 652200101231332.mat sampling done
# 652200101231656.mat sampling done
# 652200101240601.mat sampling done
# 652200101240740.mat sampling done
# 652200101241025.mat sampling done
# 652200101241310.mat sampling done
# 652200101241531.mat sampling done
# 652200101241852.mat sampling done
# 652200101250429.mat sampling done
# 652200101250639.mat sampling done
# 652200101250805.mat sampling done
# 652200101250939.mat sampling done
# 652200101251202.mat sampling done
# 652200101251438.mat sampling done
# 652200101251620.mat sampling done
# 652200101251835.mat sampling done
# 652200101260633.mat sampling done
# 652200101260932.mat sampling done
# 652200101261200.mat sampling done
# 652200101261501.mat sampling done
# 652200101261650.mat sampling done
# 652200101261810.mat sampling done
# 652200101270306.mat sampling done
# 652200101270434.mat sampling done
# 652200101270633.mat sampling done
# 652200101270954.mat sampling done
# 652200101271115.mat sampling done
# 652200101271304.mat sampling done
# 652200101271447.mat sampling done
# 652200101271722.mat sampling done
# 652200101280616.mat sampling done
# 652200101280800.mat sampling done
# 652200101281020.mat sampling done
# 652200101281241.mat sampling done
# 652200101281527.mat sampling done
# 652200101281840.mat sampling done
# 652200101290338.mat sampling done
# 652200101290637.mat sampling done
# 652200101290810.mat sampling done
# 652200101290953.mat sampling done
# 652200101291229.mat sampling done
# 652200101291448.mat sampling done
# 652200101291716.mat sampling done
# 652200101291935.mat sampling done
# 652200101300345.mat sampling done
# 652200101300631.mat sampling done
# 652200101300954.mat sampling done
# 652200101301305.mat sampling done
# 652200101301455.mat sampling done
# 652200101301736.mat sampling done
# 652200101310547.mat sampling done
# 652200101310938.mat sampling done
# 652200101311513.mat sampling done
# 652200102011019.mat sampling done
# 652200102011150.mat sampling done
# 652200102020447.mat sampling done
# 652200102020908.mat sampling done
# 652200102021147.mat sampling done
# 652200102021522.mat sampling done
# 652200102021950.mat sampling done
# 652200102030308.mat sampling done
# 652200102030411.mat sampling done
# 652200102030742.mat sampling done
# 652200102031027.mat sampling done
# 652200102031300.mat sampling done
# 652200102031347.mat sampling done
# 652200102031621.mat sampling done
# 652200102032035.mat sampling done
# 652200102040509.mat sampling done
# 652200102040755.mat sampling done
# 652200102041013.mat sampling done
# 652200102041241.mat sampling done
# 652200102041535.mat sampling done
# 652200102041930.mat sampling done
# 652200102050342.mat sampling done
# 652200102050653.mat sampling done
# 652200102051052.mat sampling done
# 652200102051343.mat sampling done
# 652200102051537.mat sampling done
# 652200102051801.mat sampling done
# 652200102060534.mat sampling done
# 652200102060700.mat sampling done
# 652200102060719.mat sampling done
# 652200102060911.mat sampling done
# 652200102061149.mat sampling done
# 652200102061357.mat sampling done
# 652200102061615.mat sampling done
# 652200102061823.mat sampling done
# 652200102062035.mat sampling done
# 652200102070510.mat sampling done
# 652200102070752.mat sampling done
# 652200102070857.mat sampling done
# 652200102070931.mat sampling done
# 652200102071134.mat sampling done
# 652200102071617.mat sampling done
# 652200102072008.mat sampling done
# 652200102080602.mat sampling done
# 652200102080905.mat sampling done
# 652200102081053.mat sampling done
# 652200102081305.mat sampling done
# 652200102081451.mat sampling done
# 652200102081749.mat sampling done
# 652200102082012.mat sampling done
# 652200102090304.mat sampling done
# 652200102090430.mat sampling done
# 652200103172033.mat sampling done
# 652200103180900.mat sampling done
# 652200103181123.mat sampling done
# 652200103181228.mat sampling done
# 652200103181357.mat sampling done
# 652200103181802.mat sampling done
# 652200103182023.mat sampling done
# 652200103311608.mat sampling done
# 652200103311730.mat sampling done
# 652200104010507.mat sampling done
# 652200104010905.mat sampling done
# 652200104011236.mat sampling done
# 652200104011805.mat sampling done
# 652200104020328.mat sampling done
# 652200104020341.mat sampling done
# 652200104020547.mat sampling done
# 652200104020744.mat sampling done
# 652200104021159.mat sampling done
# 652200104021439.mat sampling done
# 652200104021651.mat sampling done
# 652200104030405.mat sampling done
# 652200104030748.mat sampling done
# 652200104031031.mat sampling done
# 652200104031257.mat sampling done
# 652200104031341.mat sampling done
# 652200104031518.mat sampling done
# 652200104031714.mat sampling done
# 652200104040611.mat sampling done
# 652200104041144.mat sampling done
# 652200104041411.mat sampling done
# 652200104041617.mat sampling done
# 652200104041808.mat sampling done
# 652200104042036.mat sampling done
# 652200104050456.mat sampling done
# 652200104050733.mat sampling done
# 652200104050925.mat sampling done
# 652200104051112.mat sampling done
# 652200104051337.mat sampling done
# 652200104052043.mat sampling done
# 652200104060508.mat sampling done
# 652200104060727.mat sampling done
# 652200104060943.mat sampling done
# 652200104061306.mat sampling done
# 652200104061524.mat sampling done
# 652200104061915.mat sampling done
# 652200104070335.mat sampling done
# 652200104070647.mat sampling done
# 652200104071050.mat sampling done
# 652200104071434.mat sampling done
# 652200104071712.mat sampling done
# 652200104072052.mat sampling done
# 652200104072317.mat sampling done
# 652200104080231.mat sampling done
# 652200104080443.mat sampling done
# 652200104080644.mat sampling done
# 652200104081001.mat sampling done
# 652200104081118.mat sampling done
# 652200104081307.mat sampling done
# 652200104081454.mat sampling done
# 652200104081724.mat sampling done
# 652200104090606.mat sampling done
# 652200104091000.mat sampling done
# 652200104091120.mat sampling done
# 652200104091307.mat sampling done
# 652200104091448.mat sampling done
# 652200104091734.mat sampling done
# 652200104100514.mat sampling done
# 652200104100802.mat sampling done
# 652200104101012.mat sampling done
# 652200104101246.mat sampling done
# 652200104101541.mat sampling done
# 652200104101843.mat sampling done
# 652200104110341.mat sampling done
# 652200104110627.mat sampling done
# 652200104110958.mat sampling done
# 652200104111340.mat sampling done
# 652200104111620.mat sampling done
# 652200104112035.mat sampling done
# 652200104120514.mat sampling done
# 652200104120654.mat sampling done
# 652200104120810.mat sampling done
# 652200104120935.mat sampling done
# 652200104121123.mat sampling done
# 652200104121255.mat sampling done
# 652200104121442.mat sampling done
# 652200104121625.mat sampling done
# 652200104121832.mat sampling done
# 652200104130345.mat sampling done
# 652200104130750.mat sampling done
# 652200104131029.mat sampling done
# 652200104131245.mat sampling done
# 652200104131538.mat sampling done
# 652200104140800.mat sampling done
# 652200104140925.mat sampling done
# 652200104141106.mat sampling done
# 652200104141249.mat sampling done
# 652200104141454.mat sampling done
# 652200104141714.mat sampling done
# 652200104141930.mat sampling done
# 652200104150216.mat sampling done
# 652200104150433.mat sampling done
# 652200104150604.mat sampling done
# 652200104150636.mat sampling done
# 652200104150842.mat sampling done
# 652200104150952.mat sampling done
# 652200104151116.mat sampling done
# 652200104151259.mat sampling done
# 652200104151435.mat sampling done
# 652200104151619.mat sampling done
# 652200104151805.mat sampling done
# 652200104160508.mat sampling done
# 652200104160716.mat sampling done
# 652200104160912.mat sampling done
# 652200104161144.mat sampling done
# 652200104161353.mat sampling done
# 652200104161603.mat sampling done
# 652200104161759.mat sampling done
# 652200104162027.mat sampling done
# 652200104170453.mat sampling done
# 652200104170727.mat sampling done
# 652200104170943.mat sampling done
# 652200104171240.mat sampling done
# 652200104171435.mat sampling done
# 652200104171701.mat sampling done
# 652200104180510.mat sampling done
# 652200104180757.mat sampling done
# 652200104180929.mat sampling done
# 652200104181224.mat sampling done
# 652200104181535.mat sampling done
# 652200104182036.mat sampling done
# 652200104190509.mat sampling done
# 652200104190804.mat sampling done
# 652200104190924.mat sampling done
# 652200104191110.mat sampling done
# 652200104191318.mat sampling done
# 652200104191502.mat sampling done
# 652200104191640.mat sampling done
# 652200104191641.mat sampling done
# 652200104191846.mat sampling done
# 652200104200651.mat sampling done
# 652200104201121.mat sampling done
# 652200104201257.mat sampling done
# 652200104201503.mat sampling done
# 652200104201652.mat sampling done
# 652200104201823.mat sampling done
# 652200104210421.mat sampling done
# 652200104210651.mat sampling done
# 652200104211052.mat sampling done
# 652200104211435.mat sampling done
# 652200104211629.mat sampling done
# 652200104211837.mat sampling done
# 652200104220911.mat sampling done
# 652200104221002.mat sampling done
# 652200104221250.mat sampling done
# 652200104221544.mat sampling done
# 652200104221925.mat sampling done
# 652200104230119.mat sampling done
# 652200104230430.mat sampling done
# 652200104230633.mat sampling done
# 652200104230955.mat sampling done
# 652200104231117.mat sampling done
# 652200104231336.mat sampling done
# 652200104231520.mat sampling done
# 652200104231658.mat sampling done
# 652200104231720.mat sampling done
# 652200104240353.mat sampling done
# 652200104240419.mat sampling done
# 652200104240425.mat sampling done
# 652200104240550.mat sampling done
# 652200104240556.mat sampling done
# 652200104240648.mat sampling done
# 652200104240702.mat sampling done
# 652200104240713.mat sampling done
# 652200104240748.mat sampling done
# 652200104240806.mat sampling done
# 652200104241039.mat sampling done
# 652200104241151.mat sampling done
# 652200104241349.mat sampling done
# 652200104241410.mat sampling done
# 652200104241554.mat sampling done
# 652200104241616.mat sampling done
# 652200104242017.mat sampling done
# 652200104250320.mat sampling done
# 652200104250403.mat sampling done
# 652200104250543.mat sampling done
# 652200104250749.mat sampling done
# 652200104251029.mat sampling done
# 652200104251107.mat sampling done
# 652200104251458.mat sampling done
# 652200104251535.mat sampling done
# 652200104251747.mat sampling done
# 652200104252014.mat sampling done
# 652200106100618.mat sampling done
# 652200106100744.mat sampling done
# 652200106101104.mat sampling done
# 652200106101333.mat sampling done
# 652200106101639.mat sampling done
# 652200106110528.mat sampling done
# 652200106110708.mat sampling done
# 652200106110921.mat sampling done
# 652200106111345.mat sampling done
# 652200106111651.mat sampling done
# 652200106112008.mat sampling done
# 652200106120743.mat sampling done
# 652200106121134.mat sampling done
# 652200106121402.mat sampling done
# 652200106121605.mat sampling done
# 652200106121825.mat sampling done
# 652200106122022.mat sampling done
# 652200106130501.mat sampling done
# 652200106130843.mat sampling done
# 652200106130932.mat sampling done
# 652200106131104.mat sampling done
# 652200106131235.mat sampling done
# 652200106131618.mat sampling done
# 652200106132016.mat sampling done
# 652200106140756.mat sampling done
# 652200106141139.mat sampling done
# 652200106141403.mat sampling done
# 652200106141607.mat sampling done
# 652200106141826.mat sampling done
# 652200106142012.mat sampling done
# 652200106150612.mat sampling done
# 652200106150931.mat sampling done
# 652200106151151.mat sampling done
# 652200106151745.mat sampling done
# 652200106160336.mat sampling done
# 652200106160752.mat sampling done
# 652200106161021.mat sampling done
# 652200106161339.mat sampling done
# 652200106161613.mat sampling done
# 652200106161827.mat sampling done
# 652200106170429.mat sampling done
# 652200106170805.mat sampling done
# 652200106171024.mat sampling done
# 652200106171339.mat sampling done
# 652200106171517.mat sampling done
# 652200106171712.mat sampling done
# 652200106180426.mat sampling done
# 652200106180751.mat sampling done
# 652200106181022.mat sampling done
# 652200106181337.mat sampling done
# 652200106181523.mat sampling done
# 652200106181913.mat sampling done
# 652200106182015.mat sampling done
# 652200106190238.mat sampling done
# 652200106190533.mat sampling done
# 652200106190703.mat sampling done
# 652200106190905.mat sampling done
# 652200106191152.mat sampling done
# 652200106191526.mat sampling done
# 652200106191646.mat sampling done
# 652200106191802.mat sampling done
# 652200106200257.mat sampling done
# 652200106200639.mat sampling done
# 652200106200711.mat sampling done
# 652200106200715.mat sampling done
# 652200106200743.mat sampling done
# 652200106200816.mat sampling done
# 652200106201120.mat sampling done
# 652200106201414.mat sampling done
# 652200106201614.mat sampling done
# 652200106201905.mat sampling done
# 652200106210912.mat sampling done
# 652200106211007.mat sampling done
# 652200106211135.mat sampling done
# 652200106211338.mat sampling done
# 652200106211612.mat sampling done
# 652200106211814.mat sampling done
# 652200106212025.mat sampling done
# 652200106220453.mat sampling done
# 652200106220503.mat sampling done
# 652200106220718.mat sampling done
# 652200106221241.mat sampling done
# 652200106221534.mat sampling done
# 652200106221846.mat sampling done
# 652200106230920.mat sampling done
# 652200106231525.mat sampling done
# 652200106231824.mat sampling done
# 652200106232051.mat sampling done
# 652200106240548.mat sampling done
# 652200106240747.mat sampling done
# 652200106240929.mat sampling done
# 652200106241153.mat sampling done
# 652200106241526.mat sampling done
# 652200106241945.mat sampling done
# 652200106250544.mat sampling done
# 652200106250829.mat sampling done
# 652200106250958.mat sampling done
# 652200106251122.mat sampling done
# 652200106251347.mat sampling done
# 652200106251516.mat sampling done
# 652200106251653.mat sampling done
# 652200106251744.mat sampling done
# 652200106252020.mat sampling done
# 652200106260153.mat sampling done
# 652200106260340.mat sampling done
# 652200106260534.mat sampling done
# 652200106260707.mat sampling done
# 652200106260907.mat sampling done
# 652200106261209.mat sampling done
# 652200106261524.mat sampling done
# 652200106261657.mat sampling done
# 652200106261948.mat sampling done
# 652200106262026.mat sampling done
# 652200106270546.mat sampling done
# 652200106270813.mat sampling done
# 652200106270954.mat sampling done
# 652200106271232.mat sampling done
# 652200106271532.mat sampling done
# 652200106272011.mat sampling done
# 652200106280309.mat sampling done
# 652200106280430.mat sampling done
# 652200106280638.mat sampling done
# 652200106280931.mat sampling done
# 652200106281307.mat sampling done
# 652200106281536.mat sampling done
# 652200106281848.mat sampling done
# 652200106290329.mat sampling done
# 652200106290637.mat sampling done
# 652200106290710.mat sampling done
# 652200106290952.mat sampling done
# 652200106291349.mat sampling done
# 652200106291526.mat sampling done
# 652200106291754.mat sampling done
# 652200106300544.mat sampling done
# 652200106300754.mat sampling done
# 652200106300932.mat sampling done
# 652200106301053.mat sampling done
# 652200106301154.mat sampling done
# 652200106301340.mat sampling done
# 652200106301612.mat sampling done
# 652200106301909.mat sampling done
# 652200106302007.mat sampling done
# 652200106302055.mat sampling done
# 652200107010704.mat sampling done
# 652200107010806.mat sampling done
# 652200107010930.mat sampling done
# 652200107011127.mat sampling done
# 652200107011428.mat sampling done
# 652200107011744.mat sampling done
# 652200107020402.mat sampling done
# 652200107020558.mat sampling done
# 652200107020900.mat sampling done
# 652200107021630.mat sampling done
# 652200107030651.mat sampling done
# 652200107030932.mat sampling done
# 652200107031207.mat sampling done
# 652200107031458.mat sampling done
# 652200107040653.mat sampling done
# 652200107040725.mat sampling done
# 652200107041105.mat sampling done
# 652200107041331.mat sampling done
# 652200107041541.mat sampling done
# 652200107041652.mat sampling done
# 652200107041812.mat sampling done
# 652200107050649.mat sampling done
# 652200107050940.mat sampling done
# 652200107051205.mat sampling done
# 652200107051457.mat sampling done
# 652200107060637.mat sampling done
# 652200107060950.mat sampling done
# 652200107061227.mat sampling done
# 652200107061459.mat sampling done
# 652200107070655.mat sampling done
# 652200107071038.mat sampling done
# 652200107071248.mat sampling done
# 652200107071643.mat sampling done
# 652200107072358.mat sampling done
# 652200107080941.mat sampling done
# 652200107081112.mat sampling done
# 652200107081333.mat sampling done
# 652200107081632.mat sampling done
# 652200107082108.mat sampling done
# 652200107090521.mat sampling done
# 652200107090800.mat sampling done
# 652200107091017.mat sampling done
# 652200107091202.mat sampling done
# 652200107091328.mat sampling done
# 652200107091451.mat sampling done
# 652200107092006.mat sampling done
# 652200107100252.mat sampling done
# 652200107100410.mat sampling done
# 652200107100746.mat sampling done
# 652200107100927.mat sampling done
# 652200107101032.mat sampling done
# 652200107111347.mat sampling done
# 652200107111524.mat sampling done
# 652200107111740.mat sampling done
# 652200107120523.mat sampling done
# 652200107120800.mat sampling done
# 652200107121024.mat sampling done
# 652200107121240.mat sampling done
# 652200107121532.mat sampling done
# 652200107121809.mat sampling done
# 652200107130634.mat sampling done
# 652200107130932.mat sampling done
# 652200107131103.mat sampling done
# 652200107131241.mat sampling done
# 652200107131428.mat sampling done
# 652200107131856.mat sampling done
# 652200107140334.mat sampling done
# 652200107140655.mat sampling done
# 652200107140941.mat sampling done
# 652200107141249.mat sampling done
# 652200107141533.mat sampling done
# 652200107141810.mat sampling done
# 652200107150645.mat sampling done
# 652200107150937.mat sampling done
# 652200107151201.mat sampling done
# 652200107151457.mat sampling done
# 652200107160636.mat sampling done
# 652200107161111.mat sampling done
# 652200107161255.mat sampling done
# 652200107161524.mat sampling done
# 652200107170631.mat sampling done
# 652200107170934.mat sampling done
# 652200107171016.mat sampling done
# 652200107171108.mat sampling done
# 652200107171253.mat sampling done
# 652200107171436.mat sampling done
# 652200107171640.mat sampling done
# 652200107180523.mat sampling done
# 652200107180629.mat sampling done
# 652200107180705.mat sampling done
# 652200107180924.mat sampling done
# 652200107181128.mat sampling done
# 652200107181330.mat sampling done
# 652200107181658.mat sampling done
# 652200107190340.mat sampling done
# 652200107190641.mat sampling done
# 652200107190814.mat sampling done
# 652200107190953.mat sampling done
# 652200107191112.mat sampling done
# 652200107191242.mat sampling done
# 652200107191435.mat sampling done
# 652200107191614.mat sampling done
# 652200107191710.mat sampling done
# 652200107200550.mat sampling done
# 652200107200752.mat sampling done
# 652200107200928.mat sampling done
# 652200107201125.mat sampling done
# 652200107210850.mat sampling done
# 652200107220314.mat sampling done
# 652200107220435.mat sampling done
# 652200107220716.mat sampling done
# 652200107220936.mat sampling done
# 652200107221204.mat sampling done
# 652200107221724.mat sampling done
# 652200107230310.mat sampling done
# 652200107230642.mat sampling done
# 652200107230814.mat sampling done
# 652200107230933.mat sampling done
# 652200107231010.mat sampling done
# 652200107231109.mat sampling done
# 652200107231241.mat sampling done
# 652200107231433.mat sampling done
# 652200107231611.mat sampling done
# 652200107231715.mat sampling done
# 652200107240525.mat sampling done
# 652200107240724.mat sampling done
# 652200107240929.mat sampling done
# 652200107241156.mat sampling done
# 652200107241253.mat sampling done
# 652200107241356.mat sampling done
# 652200107241551.mat sampling done
# 652200107241804.mat sampling done
# 652200107242024.mat sampling done
# 652200107250501.mat sampling done
# 652200107250744.mat sampling done
# 652200107250913.mat sampling done
# 652200107251135.mat sampling done
# 652200107261546.mat sampling done
# 652200107261746.mat sampling done
# 652200107262014.mat sampling done
# 652200107270327.mat sampling done
# 652200107270708.mat sampling done
# 652200107270909.mat sampling done
# 652200107271142.mat sampling done
# 652200107271327.mat sampling done
# 652200107271609.mat sampling done
# 652200107271831.mat sampling done
# 652200107272036.mat sampling done
# 652200107280618.mat sampling done
# 652200107280829.mat sampling done
# 652200107281037.mat sampling done
# 652200107281220.mat sampling done
# 652200107281436.mat sampling done
# 652200107281717.mat sampling done
# 652200107281911.mat sampling done

# %%
# 转化为excel表格存储
excel_columns = ['WSHR']
for var_list in all_var_groups_dict.values():
    excel_columns.extend(var_list)

excel_data = pd.DataFrame(np.squeeze(sampling_data_array).T, columns=excel_columns)
excel_data.to_excel(os.path.join(sample_save_path, 'sampling_data_array.xlsx'), index=False)
